# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('jobs_in_data.csv')
data
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
# jobs trend by jobs category

job_category_column = data['job_category']
year_column = data['work_year']
my_data = pd.DataFrame({'Year':year_column, 'Job Category':job_category_column})
my_data

Jobs = my_data['Job Category']
Years = my_data['Year']

job_counts = my_data.groupby(['Year', 'Job Category']).size().reset_index(name='count')
print(job_counts)
# Plot the graph
plt.figure(figsize=(10, 6))

# Iterate through unique job categories
for job_category in job_counts['Job Category'].unique():
    subset = job_counts[job_counts['Job Category'] == job_category]
    plt.plot(subset['Year'], subset['count'],marker = 'o', label=job_category)

plt.title('Job Counts by Category and Year')
plt.xlabel('Year')
plt.ylabel('Job Count')
plt.legend()
plt.show()
# Out:
#     Year                    Job Category  count
# 0   2020                   Data Analysis     15
# 1   2020                Data Engineering     17
# 2   2020       Data Science and Research     29
# 3   2020         Machine Learning and AI     10
# 4   2021                   Data Analysis     28
# 5   2021  Data Architecture and Modeling      5
# 6   2021                Data Engineering     45
# 7   2021    Data Management and Strategy      1
# 8   2021       Data Science and Research     72
# 9   2021       Leadership and Management      9
# 10  2021         Machine Learning and AI     37
# 11  2022            BI and Visualization      8
# 12  2022              Cloud and Database      2
# 13  2022                   Data Analysis    289
# 14  2022  Data Architecture and Modeling     46
# 15  2022                Data Engineering    499
# 16  2022    Data Management and Strategy     12
# 17  2022     Data Quality and Operations     12
# 18  2022       Data Science and Research    500
# ...

# %%
# jobs count by jobs category

job_category_column = data['job_category']
category_count = job_category_column.value_counts()

Jobs_count_list = []
Category_list = []

for job, category in category_count.items():
    Jobs_count_list.append(job)
    Category_list.append(category)

print(Jobs_count_list)
print(Category_list)

x_axis = range(0,3000,300)
y_axis = Jobs_count_list
plt.xlabel('category')
plt.ylabel('Count')
plt.title('Jobs Count by Jobs Category')
color = ['blue', 'orange', 'green','red', 'violet','brown', 'pink','yellow', 'black', 'gray']
y_axis.reverse()
plt.barh(y_axis, x_axis, label = Category_list, color = color)
# Out:
# ['Data Science and Research', 'Data Engineering', 'Data Analysis', 'Machine Learning and AI', 'Leadership and Management', 'BI and Visualization', 'Data Architecture and Modeling', 'Data Management and Strategy', 'Data Quality and Operations', 'Cloud and Database']
# [3014, 2260, 1457, 1428, 503, 313, 259, 61, 55, 5]
# <BarContainer object of 10 artists>

# %%
data_science_and_research_job_trend =data[data['job_category'] == 'Data Science and Research'].groupby('work_year')['job_category'].count()
data_science_and_research_job_trend.plot(kind='line',color='red', marker='o', title='Data Science Job Trends Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Jobs')
plt.show()
